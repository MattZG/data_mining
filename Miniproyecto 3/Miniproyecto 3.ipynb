# Run
# 147115  2.177660   1  11.28360  -1.032340 -1.88066 -11.077800   2.14537
# 147115 -3.002840  -1  17.14920 -11.713500  5.04474  11.464700  12.75360
# 147115  2.965600   1  15.82030  -1.472800  2.25895 -15.588800   2.69667
# 147115  1.007210   1  25.12730   4.087860  2.59641  24.656300   4.84272
# 147115 -1.371540  -1  13.88710  -0.277757 -2.42560 -13.670800   2.44145
# ...          ...  ..       ...        ...      ...        ...       ...
# 146511  2.690370  -1   1.80181   0.668609 -1.58437   0.537805   1.71967
# 146511  1.092010   1  14.69110  -1.418020 -2.28117 -14.443500   2.68598
# 146511 -3.047630   1  72.81740 -11.074900 -9.28179 -71.369300  14.45010
# 146511  0.808132  -1   8.58671   0.378009  3.07828   8.007050   3.10141
# 146511  1.410440   1  52.10880  16.807500 -4.60510  49.108400  17.42700
#
#             eta2      phi2  Q2         M
# Run
# 147115 -2.344030 -2.072810  -1   8.94841
# 147115  0.808077  2.734920   1  15.89300
# 147115 -2.455080  2.148570   1  38.38770
# 147115  2.330210  0.565865  -1   3.72862
# 147115 -2.423700 -1.684810  -1   2.74718
# ...          ...       ...  ..       ...
# 146511  0.307851 -1.171470   1   8.44779
# 146511 -2.383880 -2.126960   1  20.71540
# 146511 -2.300410 -2.444050  -1  12.71350
# 146511  1.677170  1.448610   1   4.69670
# 146511  1.759250 -0.267427  -1  36.50430
#
# [100000 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 147115 to 146511
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   E1      100000 non-null  float64
#  1   px1     100000 non-null  float64
#  2   py1     100000 non-null  float64
#  3   pz1     100000 non-null  float64
#  4   pt1     100000 non-null  float64
#  5   eta1    100000 non-null  float64
#  6   phi1    100000 non-null  float64
#  7   Q1      100000 non-null  int64
#  8   E2      100000 non-null  float64
#  9   px2     100000 non-null  float64
#  10  py2     100000 non-null  float64
#  11  pz2     100000 non-null  float64
#  12  pt2     100000 non-null  float64
#  13  eta2    100000 non-null  float64
#  14  phi2    100000 non-null  float64
#  15  Q2      100000 non-null  int64
#  16  M       100000 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 13.7 MB

# %%
df = df.copy()
df['M'].fillna(df['M'].median(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 147115 to 146511
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   E1      100000 non-null  float64
#  1   px1     100000 non-null  float64
#  2   py1     100000 non-null  float64
#  3   pz1     100000 non-null  float64
#  4   pt1     100000 non-null  float64
#  5   eta1    100000 non-null  float64
#  6   phi1    100000 non-null  float64
#  7   Q1      100000 non-null  int64
#  8   E2      100000 non-null  float64
#  9   px2     100000 non-null  float64
#  10  py2     100000 non-null  float64
#  11  pz2     100000 non-null  float64
#  12  pt2     100000 non-null  float64
#  13  eta2    100000 non-null  float64
#  14  phi2    100000 non-null  float64
#  15  Q2      100000 non-null  int64
#  16  M       100000 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 13.7 MB

# %%
df.nunique()
# Out:
# E1      95669
# px1     97213
# py1     97153
# pz1     98152
# pt1     91788
# eta1    94037
# phi1    94641
# Q1          2
# E2      95425
# px2     97392
# py2     97410
# pz2     97924
# pt2     92789
# eta2    89752
# phi2    94494
# Q2          2
# M       93244
# dtype: int64

# %%
df.iloc[:, 0:17].hist(figsize = (20,20))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 df.iloc[:, 0:17].hist(figsize = (20,20))
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.describe()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_sc = scaler.fit_transform(df)
df = pd.DataFrame(data = df_sc, columns = df.columns)
df
# Out:
#              E1      px1        py1       pz1       pt1      eta1      phi1  \
# 0      0.540509 -0.555559  0.768266 -1.081118 -0.128502 -1.462644  1.198101
# 1     -0.723617 -0.319885 -0.056580 -0.069855 -0.824926 -0.659534 -1.680670
# 2     -0.264329 -0.866608  0.138037  0.469594 -0.222071  1.015351  1.635954
# 3      0.702626  0.550264  0.868940  1.266859 -0.028273  1.561062  0.547689
# 4      0.606899  0.210143 -1.099091 -1.125974  0.040822 -1.388150 -0.774167
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995 -0.585291 -0.805220  0.369864  0.094502 -0.207356  0.235836  1.483010
# 99996 -0.436051  0.575841  1.109909 -0.108104  0.212939 -0.232821  0.594812
# 99997 -0.782483 -0.254339 -0.036436 -0.020969 -0.897929 -0.450698 -1.705559
# 99998  0.437348  0.836761  0.868480  1.035436  0.163103  1.321289  0.437063
# 99999 -0.698672  0.055969  0.393209 -0.072520 -0.715336 -0.532488  0.771762
#
#              Q1        E2       px2       py2       pz2       pt2      eta2  \
# 0      1.005495 -0.699865 -0.078337 -0.152278 -0.154441 -0.935490 -1.306771
# 1     -0.994535 -0.574400 -0.891995  0.373617  0.212523 -0.084141  0.506844
# 2      1.005495 -0.602825 -0.111890  0.162072 -0.227874 -0.891247 -1.370666
# 3      1.005495 -0.403748  0.311704  0.187698  0.427266 -0.719018  1.382627
# 4     -0.994535 -0.644176 -0.020855 -0.193659 -0.196651 -0.911729 -1.352611
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995 -0.994535 -0.902680  0.051236 -0.129778  0.034647 -0.969654  0.219031
# 99996  1.005495 -0.626978 -0.107717 -0.182691 -0.209230 -0.892105 -1.329700
# 99997  1.005495  0.616341 -0.843348 -0.714298 -1.135912  0.052010 -1.281674
# 99998 -0.994535 -0.757551  0.029099  0.224290  0.156237 -0.858765  1.006890
# 99999  1.005495  0.173385  1.280647 -0.359164  0.825316  0.290917  1.054116
#
#            phi2        Q2         M
# 0     -1.152542 -0.995789 -0.834329
# 1      1.493397  1.004229 -0.559255
# 2      1.170699  1.004229  0.331756
# 3      0.299655 -0.995789 -1.041084
# 4     -0.939006 -0.995789 -1.079958
# ...         ...       ...       ...
# 99995 -0.656489  1.004229 -0.854158
# 99996 -1.182344  1.004229 -0.368240
# 99997 -1.356855 -0.995789 -0.685194
# 99998  0.785475  1.004229 -1.002738
# 99999 -0.158948 -0.995789  0.257155
#
# [100000 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split

x = df.iloc[:, 0:7]
y = df['Q1']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
from sklearn.ensemble import RandomForestRegressor 
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()

#model = RandomForestRegressor(n_estimators = 100)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 7
#       4 model = KNeighborsClassifier()
#       6 #model = RandomForestRegressor(n_estimators = 100)
# ----> 7 model.fit(X_train, y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:233, in KNeighborsClassifier.fit(self, X, y)
#     211 @_fit_context(
#     212     # KNeighborsClassifier.metric is not validated yet
#     213     prefer_skip_nested_validation=False
#     214 )
#     215 def fit(self, X, y):
#     216     """Fit the k-nearest neighbors classifier from the training dataset.
#     217
#     218     Parameters
#    (...)
#     231         The fitted k-nearest neighbors classifier.
#     232     """
# --> 233     return self._fit(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py:480, in NeighborsBase._fit(self, X, y)
#     477 else:
#     478     self.outputs_2d_ = True
# --> 480 check_classification_targets(y)
#     481 self.classes_ = []
#     482 # Using `dtype=np.intp` is necessary since `np.bincount`
#     483 # (called in _classification.py) fails when dealing
#     484 # with a float64 array on 32bit systems.
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py:216, in check_classification_targets(y)
#     208 y_type = type_of_target(y, input_name="y")
#     209 if y_type not in [
#     210     "binary",
#     211     "multiclass",
#    (...)
#     214     "multilabel-sequences",
#     215 ]:
# --> 216     raise ValueError(
#     217         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     218         "classifier, which expects discrete classes on a "
#     219         "regression target with continuous values."
#     220     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
from sklearn.metrics import mean_squared_error

y_pred = model.predict(X_test)
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.07329451406912045

# %%
model = RandomForestRegressor(n_estimators = 100)
model.fit(X_train, y_train)

# %%
print(mean_squared_error(y_test, y_pred))

# %%
model = RandomForestRegressor(n_estimators = 100)
model.fit(X_train, y_train)

# %%
print(mean_squared_error(y_test, y_pred))
